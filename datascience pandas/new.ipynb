# %%
import pandas as pd
import numpy as np

# %%
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'],
        'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4],
        'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
#construct a dataframe from this data
df=pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
)

# %%
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
#finding shape of dataframe
df.shape
# Out:
# (10, 4)

# %%
#find the data types of columns
df.dtypes
# Out:
# birds        object
# age         float64
# visits        int64
# priority     object
# dtype: object

# %%
#find the summary and information of data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birds     10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
#summary

df.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   4.437500   2.900000
# std    2.007797   0.875595
# min    1.500000   2.000000
# 25%    3.375000   2.000000
# 50%    4.000000   3.000000
# 75%    5.625000   3.750000
# max    8.000000   4.000000

# %%
#print first 3 rows of the data

df.head(3)
# Out:
#      birds  age  visits priority
# a   Cranes  3.5       2      yes
# b   Cranes  4.0       4      yes
# c  plovers  1.5       3       no

# %%
#print last 3 rows 

df.tail(3)
# Out:
#         birds  age  visits priority
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
#find the missing value count

df.isnull().sum()
# Out:
# birds       0
# age         2
# visits      0
# priority    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# birds       0
# age         2
# visits      0
# priority    0
# dtype: int64

# %%
#find the null values in age column and non null values

df['age'].isna().value_counts()
# Out:
# False    8
# True     2
# Name: age, dtype: int64

# %%
#print all the rows with name and age column  as dataframe

df[['age','birds']]
# Out:
#    age       birds
# a  3.5      Cranes
# b  4.0      Cranes
# c  1.5     plovers
# d  NaN  spoonbills
# e  6.0  spoonbills
# f  3.0      Cranes
# g  5.5     plovers
# h  NaN      Cranes
# i  8.0  spoonbills
# j  4.0  spoonbills

# %%
#select 2,3,7 rows and birs, age , visit              index locking based on row index and col index

df.iloc[[2,3,7],[0,1,2]]                            #locked row  index=2,3,7     #locked col index =0,1,2
                                                   #can also define range like [2:7],[0;3]
# Out:
#         birds  age  visits
# c     plovers  1.5       3
# d  spoonbills  NaN       4
# h      Cranes  NaN       2

# %%
#select the row where no of visit < 4

df[df['visits']<4]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
#select the rows with col birds,visits where age is missing
#select the rows where the age is between 2 and 4 inclusive
#find the no of each type of bird in the dataframe

# %%
#select the rows with col birds,visits where age is missing
df[['birds','visits']][df['age'].isnull()]
# Out:
#         birds  visits
# d  spoonbills       4
# h      Cranes       2

# %%
#select the rows where the age is between 2 and 4 inclusive


df[(df['age']>=2) & (df['age']<=4)]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# f      Cranes  3.0       4       no
# j  spoonbills  4.0       2       no

# %%
#find the no of each type of bird in the dataframe

df['birds'].value_counts()
# Out:
# Cranes        4
# spoonbills    4
# plovers       2
# Name: birds, dtype: int64

# %%
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
# list of birds with priority yes

df[df['priority']=='yes']
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# d  spoonbills  NaN       4      yes
# h      Cranes  NaN       2      yes

# %%
# type of birds with priority yes

df[['birds']][df['priority']=='yes']
# Out:
#         birds
# a      Cranes
# b      Cranes
# d  spoonbills
# h      Cranes

# %%
# count of priority ==no

df['priority'].value_counts()
# Out:
# no     6
# yes    4
# Name: priority, dtype: int64

# %%
#birds whose visit greater than 2 and age is less than 4

df[['birds']][(df['visits']>2) & (df['age']<4)]
# Out:
#      birds
# c  plovers
# f   Cranes

# %%
# age and type of birds with max visits

a=df['visits'].max()
df[['age','birds']][df['visits']==a]
# Out:
#    age       birds
# b  4.0      Cranes
# d  NaN  spoonbills
# f  3.0      Cranes

# %%
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
df['age'].mean()
# Out:
# 4.4375

# %%
#fill age values with mean

df[['age']].fillna(4.4375)
# Out:
#       age
# a  3.5000
# b  4.0000
# c  1.5000
# d  4.4375
# e  6.0000
# f  3.0000
# g  5.5000
# h  4.4375
# i  8.0000
# j  4.0000

# %%
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
#how many cranes have age greater than 3

df[['birds']][df['age']>3].value_counts()
# Out:
# birds
# spoonbills    3
# Cranes        2
# plovers       1
# dtype: int64

# %%
#Group by

#find the total no of visits of birds crane
df.groupby('birds')['visits'].sum()
# Out:
# birds
# Cranes        12
# plovers        5
# spoonbills    12
# Name: visits, dtype: int64

# %%
df[['visits']][df['birds']=='Cranes'].sum()
# Out:
# visits    12
# dtype: int64

# %%
#calculate the average age of each bird

df.groupby('birds')['age'].mean()
# Out:
# birds
# Cranes        3.5
# plovers       3.5
# spoonbills    6.0
# Name: age, dtype: float64

# %%
#sort the data frame first by values in age in descending order then by visit in ascending order

df.sort_values(by=['age','visits'],ascending=[False,True])    #priority is given to age then for multiple values in second column changed to ascending
# Out:
#         birds  age  visits priority
# i  spoonbills  8.0       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# j  spoonbills  4.0       2       no
# b      Cranes  4.0       4      yes
# a      Cranes  3.5       2      yes
# f      Cranes  3.0       4       no
# c     plovers  1.5       3       no
# h      Cranes  NaN       2      yes
# d  spoonbills  NaN       4      yes

# %%
#append a new row k to the data frame with your choice of values

df.loc['k']=['arctic tern',10,5,'yes']

# %%
df
# Out:
#          birds   age  visits priority
# a       Cranes   3.5       2      yes
# b       Cranes   4.0       4      yes
# c      plovers   1.5       3       no
# d   spoonbills   NaN       4      yes
# e   spoonbills   6.0       3       no
# f       Cranes   3.0       4       no
# g      plovers   5.5       2       no
# h       Cranes   NaN       2      yes
# i   spoonbills   8.0       3       no
# j   spoonbills   4.0       2       no
# k  arctic tern  10.0       5      yes

# %%
df.loc['l']=['siberian crane',9,4,'yes']

# %%
df.loc['m']=['pelican',5,3,'no']

# %%
df
# Out:
#             birds   age  visits priority
# a          Cranes   3.5       2      yes
# b          Cranes   4.0       4      yes
# c         plovers   1.5       3       no
# d      spoonbills   NaN       4      yes
# e      spoonbills   6.0       3       no
# f          Cranes   3.0       4       no
# g         plovers   5.5       2       no
# h          Cranes   NaN       2      yes
# i      spoonbills   8.0       3       no
# j      spoonbills   4.0       2       no
# k     arctic tern  10.0       5      yes
# l  siberian crane   9.0       4      yes
# m         pelican   5.0       3       no

# %%
# remove or drop the desired row using index

df=df.drop('h')
df
# Out:
#             birds   age  visits priority
# a          Cranes   3.5       2      yes
# b          Cranes   4.0       4      yes
# c         plovers   1.5       3       no
# d      spoonbills   NaN       4      yes
# e      spoonbills   6.0       3       no
# f          Cranes   3.0       4       no
# g         plovers   5.5       2       no
# i      spoonbills   8.0       3       no
# j      spoonbills   4.0       2       no
# k     arctic tern  10.0       5      yes
# l  siberian crane   9.0       4      yes
# m         pelican   5.0       3       no

# %%
#replace the priority column with yes=1 and no=0

df['priority']=df['priority'].map({'yes':1,'no':0})

df
# Out:
#             birds   age  visits  priority
# a          Cranes   3.5       2         1
# b          Cranes   4.0       4         1
# c         plovers   1.5       3         0
# d      spoonbills   NaN       4         1
# e      spoonbills   6.0       3         0
# f          Cranes   3.0       4         0
# g         plovers   5.5       2         0
# i      spoonbills   8.0       3         0
# j      spoonbills   4.0       2         0
# k     arctic tern  10.0       5         1
# l  siberian crane   9.0       4         1
# m         pelican   5.0       3         0

# %%
#change the name cranes into trumpeters

df['birds']=df['birds'].replace({'Cranes':'trumpeters'})
df
# Out:
#             birds   age  visits  priority
# a      trumpeters   3.5       2         1
# b      trumpeters   4.0       4         1
# c         plovers   1.5       3         0
# d      spoonbills   NaN       4         1
# e      spoonbills   6.0       3         0
# f      trumpeters   3.0       4         0
# g         plovers   5.5       2         0
# i      spoonbills   8.0       3         0
# j      spoonbills   4.0       2         0
# k     arctic tern  10.0       5         1
# l  siberian crane   9.0       4         1
# m         pelican   5.0       3         0
